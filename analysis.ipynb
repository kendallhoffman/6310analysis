# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('smartphone_survey_data_11_27_23.csv')

data = data.drop(['StartDate', 'EndDate',  'RecordedDate', 'RecipientLastName', 'RecipientFirstName' , 'RecipientEmail',
                  'ExternalReference', 'LocationLatitude', 'LocationLongitude', 'IPAddress', 
                  'DistributionChannel', 'UserLanguage', 'Duration (in seconds)', 'Q23_Id', 'Q23_Name', 'Q23_Size',
                  'Q23_Type', 'Q30_Id', 'Q30_Name', 'Q30_Size', 'Q30_Type'], axis=1)

#drop rows that aren't 100% progress (aka finished)
data = data[data['Finished'] == 'True']
#drop survey previews
data = data[data['Status'] == 'IP Address']

# %%
#convert q3 object to a list 
data['Q3'] = data['Q3'].astype(str) 
data['Q3'] = data['Q3'].str.split(',')
    
#convert q3a object to a list 
data['Q3a'] = data['Q3a'].astype(str) 
data['Q3a'] = data['Q3a'].str.split(',')

#convert q11 object to a list 
data['Q11'] = data['Q11'].astype(str) 
data['Q11'] = data['Q11'].str.split(',')

# %%
pd.set_option('display.max_columns', None)
data.head()
# Out:
#        Status Progress Finished         ResponseId      QA  \
# 3  IP Address      100     True  R_3g2bTYDfLIINVAf  jk2799
# 4  IP Address      100     True  R_1HqmafMs0Fe16xD   31213
# 5  IP Address      100     True  R_2SGdVm5f06Y6nMt   30805
# 6  IP Address      100     True  R_2yfTdqN2x64Omdd   31174
# 7  IP Address      100     True  R_2ZNvd1fP8lgec3E   25174
#
#                                     Q1  Q2  \
# 3  iPhone 13/13 mini/13 Pro/13 Pro Max   1
# 4  iPhone 14/14 Plus/14 Pro/14 Pro Max   1
# 5  iPhone 14/14 Plus/14 Pro/14 Pro Max   1
# 6  iPhone 13/13 mini/13 Pro/13 Pro Max   1
# 7  iPhone 14/14 Plus/14 Pro/14 Pro Max  3+
#
#                                                   Q3 Q3_17_TEXT  \
# 3  [Texting/messaging, Browsing/searching the int...        NaN
# 4  [Texting/messaging, Browsing/Posting on social...        NaN
# 5  [Texting/messaging, Phone/video calls, Browsin...        NaN
# 6  [Texting/messaging, Phone/video calls, Listeni...        NaN
# 7  [Texting/messaging, Phone/video calls, Browsin...        NaN
#
#                                                  Q3a Q3a_11_TEXT Q4_1 Q4_2  \
# 3                                              [nan]         NaN    8    5
# 4           [Facebook, Instagram, YouTube, LinkedIn]         NaN  NaN  NaN
# 5  [Instagram, YouTube, Snapchat, WhatsApp, Reddi...         NaN    5    7
# 6                                              [nan]         NaN    7    8
# 7  [Instagram, Twitter/X, Snapchat, TikTok, Whats...         NaN    4    5
#
#   Q4_3 Q4_4 Q4_5 Q4_6 Q4_7 Q4_8      Q5         Q6      Q7 Q7_4_TEXT  \
# 3    4    6    7    3    1    2  Rarely  4-6 hours  Social       NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  Weekly  6-7 hours  Social       NaN
# 5    6    3    8    2    4    1  Weekly  4-6 hours  Social       NaN
# 6    2    6    3    1    4    5  Weekly  4-6 hours  Social       NaN
# 7    7    6    8    1    3    2   Never  8-9 hours  Social       NaN
#
#                                                   Q8   Q9  \
# 3                        iMessage, Instagram, Safari   No
# 4                       Youtube, Instagram, iMessage   No
# 5  I think Instagram, Youtube, and Two Dots (a ga...  Yes
# 6                          Instagram, Youtube, Gmail   No
# 7                       iMessage, Instragram, Photos   No
#
#                                                  Q10  \
# 3            I don't think its been a problem so far
# 4  I feel the necessity to use the smartphone to ...
# 5  I manage smartphone screen time because it fee...
# 6                            Do not really care much
# 7                  Because it hasn't become an issue
#
#                                                  Q11 Q11_11_TEXT Q12_1 Q12_2  \
# 3  [Keep the phone on silent,  face-down,  out of...         NaN   NaN     3
# 4  [Disable non-essential notifications, Keep the...         NaN     4     2
# 5  [Keep the phone on silent,  face-down,  out of...         NaN   NaN     1
# 6  [Keep the phone on silent,  face-down,  out of...         NaN   NaN     3
# 7  [Disable non-essential notifications, Keep the...         NaN     5     5
#
#   Q12_3 Q12_4 Q12_5 Q12_6 Q12_7 Q12_8 Q12_9 Q12_10 Q12_11  \
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN      2    NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 5   NaN     1   NaN     3   NaN   NaN   NaN    NaN    NaN
# 6   NaN     4   NaN   NaN   NaN   NaN   NaN      2    NaN
# 7   NaN   NaN   NaN   NaN     5     5   NaN    NaN    NaN
#
#                     Q13_1                   Q13_2                   Q13_3  \
# 3  Multiple times per day  Several times per week                   Never
# 4  Multiple times per day                  Rarely                   Never
# 5  Multiple times per day  Multiple times per day  Multiple times per day
# 6  Multiple times per day                  Rarely                   Never
# 7  Multiple times per day   A few times per month                   Never
#
#                     Q13_4                  Q13_5                   Q13_6  \
# 3                   Never                 Rarely  Multiple times per day
# 4                   Never                  Never  Multiple times per day
# 5  Several times per week           Once per day  Multiple times per day
# 6                   Never  A few times per month  Multiple times per day
# 7                   Never                  Never  Multiple times per day
#
#                     Q13_7                  Q13_8                    Q14  \
# 3  Multiple times per day                  Never  Extremely comfortable
# 4                  Rarely                 Rarely  Extremely comfortable
# 5  Multiple times per day  A few times per month   Somewhat comfortable
# 6  Several times per week                  Never  Extremely comfortable
# 7            Once per day                  Never  Extremely comfortable
#
#                                                  Q20                    Q21  \
# 3  It does not have any significant impact on my ...  No significant impact
# 4  It has a negative impact on my life or well-being        Negative impact
# 5  It has a positive impact on my life or well-being        Negative impact
# 6  It has a positive impact on my life or well-being        Positive impact
# 7  It does not have any significant impact on my ...        Positive impact
#
#               Q24        Q25        Q26        Q27       Q28  Q31        Q32  \
# 3  3 hours 38 min     Social  Instagram   Messages   Youtube  195   Messages
# 4             6.5  Utilities    Youtube  Instagram  iMessage  194    Message
# 5         6 hours     Social    Youtube   Two Dots     Clock  154    YouTube
# 6               5     Social  Instagram   Messages      ESPN  170  Instagram
# 7        8 hours      Social   Messages  Instagram   Spotify  214   Messages
#
#     Q50   Q33 Q38     Q39                       Q40 Q40_7_TEXT     Q41 Q42  \
# 3     4     3  20    Male  Asian / Pacific Islander        NaN  Junior   6
# 4  12.5     3  21  Female  Asian / Pacific Islander        NaN  Senior   4
# 5    14   178  21  Female  Asian / Pacific Islander        NaN  Junior   5
# 6    15   175  20    Male  Asian / Pacific Islander        NaN  Junior   5
# 7    16  1282  21  Female         White / Caucasian        NaN  Senior   5
#
#   Q44  Q43 Q45               Q46  Q47    Q48
# 3   0   No  No  No, not employed  NaN  10-12
# 4   0  Yes  No  No, not employed  NaN  13-15
# 5   0   No  No  No, not employed  NaN  10-12
# 6   3   No  No  No, not employed  NaN  13-15
# 7   2  Yes  No    Yes, part-time    1  10-12

# %%
#dealing with the mess that is Q8
# print(data['Q8'])

#split on commas
data['Q8'] = data['Q8'].astype(str) 
data['Q8'] = data['Q8'].str.split(',')

#instances where inputted answer wasn't exactly three apps
diff_data = data[data['Q8'].apply(lambda x: len(x) != 3)]
print(diff_data['Q8'])
# Out:
# 11                  [WeChat,  Instagram]
# 17                   [WeChat,  Bilibili]
# 26                                 [nan]
# 33           [iMessage Tiktok Instagram]
# 36            [what's app and YouTube. ]
# 39    [IMessage,  Youtube and Instagram]
# 49                  [Reddit,  Instagram]
# 50        [instagram. tiktok,  twitter ]
# Name: Q8, dtype: object

# %%
#q24 -- input reported screentime from screenshot

data.dropna(subset=['Q24'], inplace=True)
print(data['Q24'])
# Out:
# 3                                        3 hours 38 min
# 4                                                   6.5
# 5                                               6 hours
# 6                                                     5
# 7                                              8 hours
# 8                                                     6
# 9                                           2hr 30 mins
# 10                                                    2
# 11                                                   10
# 12                                                    4
# 13                                  3 Hours, 40 Minutes
# 14                                                    4
# 15                                                    5
# 16                                                   6h
# 17                                                   10
# 18                                                   11
# 19                                                  2.5
# 20                                                    7
# 21                                                    5
# 22                                                    8
# 24                                                   7
# 25                                          2 hr 44 min
# 26                                                    7
# 27                                              6 hours
# 28                                                  2h
# 29                                              7 hours
# 30                                                    5
# 31                                                    4
# 32                                                    5
# 33                                            Not found
# 34                                                  1.5
# 35                                                    4
# 36                                                    3
# 37                                              5 hours
# 38                                              10h 47m
# 39    Not sure it was not being tracked when I check...
# 40                                               6h 35m
# 41                                                   5
# 42                                                    8
# 43                                            3.5 hours
# 44                                              7.3 hrs
# 45                                  9 hours and 40 mins
# 46                                                    3
# 47                                                 4:30
# 48                                                5h 6m
# 49                                                    6
# 50                                             4 hours
# 51                                                  4.5
# 52                                              7 hours
# 53                                         3 hr 43 min
# 54                                       4 hours 53 min
# 55                                                    5
# 56                                                    4
# 57                                                    3
# 58                                               8h 39m
# 62                                                  4.3
# Name: Q24, dtype: object

# %%
#Convert 'Q26' column to string
data['Q26'] = data['Q26'].astype(str)

# Convert 'Q8' column to list (if it's not already)
data['Q8'] = data['Q8'].apply(lambda x: [x] if not isinstance(x, list) else x)

# Filter rows where the string in 'Q24' is in the list in 'Q8'
estApps = data[data.apply(lambda row: row['Q26'] in row['Q8'], axis=1)]

# initialize data of lists. 
estApps_data = {'Q26': estApps['Q26'], 
        'Q8': estApps['Q8']} 
  
# Create DataFrame 
df = pd.DataFrame(estApps_data) 
  
# Print the output. 
df

#19 people included their most used app in their estimated most used apps (30%) 
# UNCLEANED THOUGH SO THIS ISNT ACTUALLY TRUE BC PEOPLE MIGHT SPELL THINGS DIFFERENTLY IN DIFFERENT QUESTIONS
# Out:
#           Q26                                  Q8
# 4     Youtube    [Youtube,  Instagram,  iMessage]
# 6   Instagram       [Instagram,  Youtube,  Gmail]
# 8   Instagram     [Instagram,  Safari,  iMessage]
# 9   Instagram    [Instagram,  Whatsapp,  Spotify]
# 13  Instagram     [Instagram,  IMessage,  Safari]
# 14   Messages     [Messages,  Snapchat,  Tik Tok]
# 15  Instagram    [Instagram,  iMessage,  Youtube]
# 20     Safari     [Safari,  Twitter(X),  Youtube]
# 27    YouTube        [YouTube,  Duolingo,  Drops]
# 28  Instagram     [Instagram,  iMessage,  G-Mail]
# 29     TikTok        [TikTok,  iMessage,  Kindle]
# 32     Tiktok      [Tiktok,  Instagram,  youtube]
# 42     TikTok       [TikTok,  iMessage,  Spotify]
# 43   Snapchat      [Snapchat,  IMessage,  TikTok]
# 55     TikTok      [TikTok,  Facetime,  Messages]
# 56     Reddit     [Reddit,  Instagram,  Facetime]
# 57  Instagram     [Instagram,  iMessage,  Safari]
# 58     WeChat  [WeChat,  Instagram,  XiaoHongShu]
# 62     Reddit       [Reddit,  Sidechat,  Onenote]

# %%
# unique counts in q26 (most used app)

data['Q26'].value_counts()

# need to clean this so that different spellings are counted as the same app

def flatten(l):
    return [item for sublist in l for item in sublist]

# print(data['Q8'])

qeight = []
for ans in data['Q8']:
    ansFull = ''.join(ans).lower()
    ansFull = ansFull.replace("and", " ").replace("tik tok","tiktok").replace("imessages", "imessage").replace(".", "").replace(",", "").replace("instragram", "instagram").replace("what's app", "whatsapp").replace("(social media)", "").replace(",", "").replace(".", "").replace("i think instagram youtube   two dots (a game) are the most used apps", "instagram, youtube")
    #added replace("twitteriaohongshu", "twitter")
    ansFull = ansFull.replace("netflitwitter", "netflix, twitter").replace(",", "").replace("twitter(x)", "twitter").replace("x", "twitter").replace("g-mail", "gmail").replace("twitteriaohongshu", "twitter")
    ans = ansFull.split(" ")
    print(ans)
    qeight.append([app.strip() for app in ans])
    
allqeight = flatten(qeight)

uniqueAllQEight = pd.Series(allqeight).value_counts()
# Out:
# ['imessage', 'instagram', 'safari']
# ['youtube', 'instagram', 'imessage']
# ['instagram', 'youtube']
# ['instagram', 'youtube', 'gmail']
# ['imessage', 'instagram', 'photos']
# ['instagram', 'safari', 'imessage']
# ['instagram', 'whatsapp', 'spotify']
# ['wechat', 'linkedin', 'gmail']
# ['wechat', 'instagram']
# ['youtube', 'music', 'slack', 'google', 'map', '']
# ['instagram', 'imessage', 'safari']
# ['messages', 'snapchat', 'tiktok']
# ['instagram', 'imessage', 'youtube']
# ['instagram', 'imessage', 'spotify']
# ['wechat', 'bilibili']
# ['instagram', 'youtube', 'chrome']
# ['imessage', 'instagram', 'spotify']
# ['safari', 'twitter', 'youtube']
# ['wechat', 'instagram', 'amazon']
# ['safari', 'tiktok', 'youtube']
# ['instagram', 'whatsapp', '', 'tiktok', '']
# ['messenger', 'instagram', 'youtube', '', '']
# ['nan']
# ['youtube', 'duolingo', 'drops']
# ['instagram', 'imessage', 'gmail']
# ['tiktok', 'imessage', 'kindle']
# ['tiktok', 'imessage', 'instagram']
# ['imessage', 'tiktok', 'snapchat']
# ['tiktok', 'instagram', 'youtube']
# ['imessage', 'tiktok', 'instagram']
# ['imessage', 'instagram', 'facetime']
# ['twitteriaohongshu', '', 'wechat', 'safari']
# ['whatsapp', '', '', 'youtube', '']
# ['spotify', 'imessage', 'tiktok']
# ['tiktok', 'wechat', 'instagram']
# ['imessage', 'youtube', '', '', 'instagram']
# ['imessage', 'facetime', 'instagram']
# ['tiktok', 'imessage', 'instagram']
# ['tiktok', 'imessage', 'spotify']
# ['snapchat', 'imessage', 'tiktok']
# ['twitter', 'monopoly', 'go', 'google', '']
# ['imessage', 'safari', 'tiktok']
# ['mail', 'red', 'bookwechat']
# ['snapchat', 'youtube', 'instagram']
# ['snapchat', 'imessage', 'instagram']
# ['reddit', 'instagram']
# ['instagram', 'tiktok', 'twitter', '']
# ['imessage', 'twitter', 'jetpack', 'joyride']
# ['imessage', 'tiktok', 'neteflitwitter']
# ['netflitwitter', 'tiktok', 'snapchat']
# ['instagram', 'tiktok', 'snapchat']
# ['tiktok', 'facetime', 'messages']
# ['reddit', 'instagram', 'facetime']
# ['instagram', 'imessage', 'safari']
# ['wechat', 'instagram', 'twitteriaohongshu']
# ['reddit', 'sidechat', 'onenote']
